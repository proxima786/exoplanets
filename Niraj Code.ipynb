# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Exo-Planet Plot-1

# %%
df1=pd.read_csv('1st Plot Ratio.csv')
df1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df1=pd.read_csv('1st Plot Ratio.csv')
#       2 df1
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# Check if "TOI-411 b" is in the 'pl_name' column
if 'LHS 1140 b' in df['pl_name (Exoplanet)'].values:
    print("LHS-1140 b exists in the 'pl_name' column.")
else:
    print("LHS-1140 b does not exist in the 'pl_name' column.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Check if "TOI-411 b" is in the 'pl_name' column
# ----> 2 if 'LHS 1140 b' in df['pl_name (Exoplanet)'].values:
#       3     print("LHS-1140 b exists in the 'pl_name' column.")
#       4 else:
#
# NameError: name 'df' is not defined

# %%
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Iterate through the DataFrame and plot scatter points
for index, row in df.iterrows():
    if row['pl_name (Exoplanet)'] == 'Earth':
        plt.scatter(row['pl_rade (Dp)'], row['st_rad (Ds)'], color='yellow', marker='*', s=100, label='Earth')
    elif row['pl_name (Exoplanet)'] == 'Kepler-452 b':
        plt.scatter(row['pl_rade (Dp)'], row['st_rad (Ds)'], color='purple', marker='*', s=100, label='Kepler-452 b')
    elif row['pl_name (Exoplanet)'] == 'Kepler-62 f':
        plt.scatter(row['pl_rade (Dp)'], row['st_rad (Ds)'], color='green', marker='*', s=100, label='Kepler-62 f')
    elif row['pl_name (Exoplanet)'] == 'KOI-4878.01':
        plt.scatter(row['pl_rade (Dp)'], row['st_rad (Ds)'], color='red', marker='*', s=100, label='KOI-4878.01')
    else:
        plt.scatter(row['pl_rade (Dp)'], row['st_rad (Ds)'], color='blue', marker='o', s=10)  # Set smaller size for other exoplanets

# Plot the line y = x passing through the origin
max_value = max(df['pl_rade (Dp)'].max(), df['st_rad (Ds)'].max())
plt.plot([0, max_value], [0, max_value], color='black', linestyle='dashed', label='y = x')

# Create custom legend entries for different markers
legend_entry = Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=10, label='Exoplanets')
legend_entry_1 = Line2D([0], [0], marker='*', color='yellow', markersize=10, label='Earth')
legend_entry_3 = Line2D([0], [0], marker='*', color='purple', markersize=10, label='Kepler-452 b')
legend_entry_4 = Line2D([0], [0], marker='*', color='green', markersize=10, label='Kepler-62 f')
legend_entry_5 = Line2D([0], [0], marker='*', color='red', markersize=10, label='KOI-4878.01')

# Set the x-axis and y-axis limits
plt.xlim(0, 2)
plt.ylim(0, 2)

# Add the custom legend entries along with the line legend
plt.legend(handles=[legend_entry_1, legend_entry, legend_entry_3, legend_entry_4, legend_entry_5], loc='upper left')

# Use LaTeX-style formatting for the axis labels
plt.xlabel('Diameter of planet ($D_p$)')
plt.ylabel('Diameter of star ($D_s$)')
plt.title('Plot of $D_s$ $v/s$ $D_p$')
plt.grid(True)
plt.savefig('Exoplanet Plot-1.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Exo-Planet Plot-2

# %%
df2=pd.read_csv('2nd Plot Ratio.csv')
df2
# Out:
#     Planet Name (Exoplanet)   Host star  Planet Orbs Max (d)  \
# 0                30 Ari B b    30 Ari B                1.010
# 1                  55 Cnc f      55 Cnc                0.792
# 2                   7 CMa b       7 CMa                1.900
# 3              BD+14 4559 b  BD+14 4559                0.780
# 4                 GJ 3293 c     GJ 3293                0.364
# ..                      ...         ...                  ...
# 132            Kepler-967 c  Kepler-967                0.568
# 133                   PH2 b         PH2                0.836
# 134               WASP-47 c     WASP-47                1.360
# 135                   Earth         Sun                1.000
# 136             KOI-4878.01    KOI-4878                1.137
#
#      Planet Rade (Dp)  Stellar Rad (Ds)  \
# 0                 NaN             1.130
# 1                 NaN             0.960
# 2                 NaN             2.300
# 3                 NaN             0.860
# ...

# %%
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

for index, row in df2.iterrows():
    if row['Planet Name (Exoplanet)'] == 'Earth':
        plt.scatter(row['Stellar Rad (Ds)'], row['Planet Orbs Max (d)'], color='yellow', marker='*', s=120, label='Earth')
    elif row['Planet Name (Exoplanet)'] == 'Kepler-452 b':
        plt.scatter(row['Stellar Rad (Ds)'], row['Planet Orbs Max (d)'], color='red', marker='*', s=120, label='Kepler-452 b')  
    elif row['Planet Name (Exoplanet)'] == 'Kepler-62 f':
        plt.scatter(row['Stellar Rad (Ds)'], row['Planet Orbs Max (d)'], color='purple', marker='*', s=120, label='Kepler-62 f')  
    elif row['Planet Name (Exoplanet)'] == 'KOI-4878.01':
        plt.scatter(row['Stellar Rad (Ds)'], row['Planet Orbs Max (d)'], color='black', marker='*', s=120, label='KOI-4878.01')
    else:
        plt.scatter(row['Stellar Rad (Ds)'], row['Planet Orbs Max (d)'], color='blue', marker='o', s=20)  # Set smaller size for other exoplanets

# Plot the line y = x passing through the origin
max_value = max(df2['Stellar Rad (Ds)'].max(), df2['Planet Orbs Max (d)'].max())
plt.plot([0, 6], [0, 6], color='black', linestyle='dashed')

# Create custom legend entries for different markers
legend_entry = Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=8, label='Exoplanets')
legend_entry_1 = Line2D([0], [0], marker='*', color='yellow', markersize=10, label='Earth')
legend_entry_3 = Line2D([0], [0], marker='*', color='red', markersize=10, label='Kepler-452 b')
legend_entry_4 = Line2D([0], [0], marker='*', color='purple', markersize=10, label='Kepler-62 f')
legend_entry_5 = Line2D([0], [0], marker='*', color='black', markersize=10, label='KOI-4878.01')

# Set the x-axis and y-axis limits
plt.xlim(0, 2)
plt.ylim(0, 2)

# Add the custom legend entries along with the line legend
plt.legend(handles=[legend_entry_1, legend_entry, legend_entry_3, legend_entry_4, legend_entry_5], loc='upper left')

plt.xlabel('$D_s$ (Diameter of Star)')
plt.ylabel('d (Semi-major axis in AU)')
plt.title('Plot of d v/s $D_s$')
plt.grid(True)
plt.savefig('Exoplanet Plot-2.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# * scale x axis from 0-2
# * scale y-axis from 0-2
# * mention kepler-452b and kepler-62f
# * add KOI-4878.01
