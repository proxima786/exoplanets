# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('1st plot ratio-1.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.read_csv('1st plot ratio-1.csv')
#       2 df
#
# NameError: name 'pd' is not defined

# %%
if 'kepler-62f' in df.columns:
    print("kepler-62f is present in the DataFrame.")
else:
    print("kepler-62f is not present in the DataFrame.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 if 'kepler-62f' in df.columns:
#       2     print("kepler-62f is present in the DataFrame.")
#       3 else:
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('1st plot ratio-1.csv')

# Create a list with your own data for the new row
new_row_data = ['Earth', 'sun', 1,1, 1, 1, 1,109.7522, 107.1428]  # Replace 0s with your data

# Add the new row to the DataFrame
df.loc[len(df)] = new_row_data

# Reset the index
df = df.reset_index(drop=True)

# Print the DataFrame after adding the new row
df
# Out:
#     pl_name (Exoplanet) hostname (Host star)  pl_orbsmax (d)  pl_rade (Dp)  \
# 0      EPIC 201595106 b       EPIC 201595106             NaN         1.200
# 1     EPIC 201757695.02       EPIC 201757695          0.0296         0.908
# 2      EPIC 206024342 c       EPIC 206024342             NaN         1.400
# 3      EPIC 212587672 b       EPIC 212587672             NaN         1.260
# 4      EPIC 212624936 b       EPIC 212624936             NaN         1.200
# ..                  ...                  ...             ...           ...
# 671        Kepler-997 b           Kepler-997          0.0400         1.070
# 672        Kepler-999 b           Kepler-999          0.0710         2.500
# 673          TOI-1860 b             TOI-1860             NaN         1.270
# 674           TOI-411 b              TOI-411             NaN         1.547
# 675               Earth                  sun          1.0000         1.000
#
#      st_rad (Ds)  Diameter of planet in terms of Earth's diameter  \
# ...

# %%
from matplotlib import rc
import matplotlib.pyplot as plt
import pandas as pd

# Set the figure size using rc
rc('figure', figsize=(25, 10))

# Read the CSV file into a DataFrame
df = pd.read_csv('1st plot ratio-1.csv')

# Create a scatter plot
plt.figure()
for index, row in df.iterrows():
    color = 'red' if row['pl_name (Exoplanet)'] == 'Earth' else 'blue'
    plt.scatter(row['pl_rade (Dp)'], row['st_rad (Ds)'], color=color, alpha=0.7)

plt.xlabel('Diameter of planet (Dp)')
plt.ylabel('Diameter of star (Ds)')
plt.title('Plot of Ds v/s Dp')

# Invert the x-axis
plt.gca().invert_xaxis()

plt.grid(True)
plt.show()

# %%
dff=pd.read_csv('2nd plot ratio-2.csv')
dff
# Out:
#     pl_name (Exoplanet) hostname (Host star)  pl_orbsmax (d)  pl_rade (Dp)  \
# 0            30 Ari B b             30 Ari B          1.0100           NaN
# 1              55 Cnc f               55 Cnc          0.7920           NaN
# 2               7 CMa b                7 CMa          1.9000           NaN
# 3          BD+14 4559 b           BD+14 4559          0.7800           NaN
# 4             GJ 3293 c              GJ 3293          0.3640           NaN
# ..                  ...                  ...             ...           ...
# 130        Kepler-712 c           Kepler-712          0.6820          4.41
# 131         Kepler-87 c            Kepler-87          1.3423          4.96
# 132        Kepler-967 c           Kepler-967          0.5680          2.86
# 133               PH2 b                  PH2          0.8360          8.98
# 134           WASP-47 c              WASP-47          1.3600           NaN
#
#      st_rad (Ds)  Diameter of planet in terms of Earth's diameter  \
# ...

# %%
# Create a list with your own data for the new row
new_row_data = ['Earth', 'sun', 1,1, 1, 1, 1,109.7522, 107.1428]  # Replace 0s with your data

# Add the new row to the DataFrame
dff.loc[len(dff)] = new_row_data

# Reset the index
dff = dff.reset_index(drop=True)

# Print the DataFrame after adding the new row
dff
# Out:
#     pl_name (Exoplanet) hostname (Host star)  pl_orbsmax (d)  pl_rade (Dp)  \
# 0            30 Ari B b             30 Ari B          1.0100           NaN
# 1              55 Cnc f               55 Cnc          0.7920           NaN
# 2               7 CMa b                7 CMa          1.9000           NaN
# 3          BD+14 4559 b           BD+14 4559          0.7800           NaN
# 4             GJ 3293 c              GJ 3293          0.3640           NaN
# ..                  ...                  ...             ...           ...
# 131         Kepler-87 c            Kepler-87          1.3423          4.96
# 132        Kepler-967 c           Kepler-967          0.5680          2.86
# 133               PH2 b                  PH2          0.8360          8.98
# 134           WASP-47 c              WASP-47          1.3600           NaN
# 135               Earth                  sun          1.0000          1.00
#
#      st_rad (Ds)  Diameter of planet in terms of Earth's diameter  \
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Read the CSV file into a DataFrame
dff = pd.read_csv('2nd plot ratio-2.csv')

# Create a scatter plot
plt.figure(figsize=(10, 6))
for index, row in dff.iterrows():
    color = 'red' if row['pl_name (Exoplanet)'] == 'Earth' else 'blue'
    plt.scatter(row['st_rad (Ds)'], row['pl_orbsmax (d)'], color=color, alpha=0.7)

plt.xlabel('Ds')
plt.ylabel('d')
plt.title('Plot of Ds v/s d')

# Invert the x-axis
plt.gca().invert_xaxis()

plt.grid(True)
plt.show()
